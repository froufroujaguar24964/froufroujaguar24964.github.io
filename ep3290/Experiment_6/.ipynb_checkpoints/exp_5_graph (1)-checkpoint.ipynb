# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
p = [13.75,13.5,13.25,13.0,12.75,12.5,12.25,12,11.95,11.9,11.85,11.8,11.75,11.7,11.65,11.6,11.55,11.5,11.45,11.4,11.35,11.3,11.25,11.2,11.15,11.1,11.05,11,10.95,10.9,10.85,10.8,10.75,10.7,10.65,10.6,10.55,10.5,10.45,10.4,10.35,10.3,10.25,10.2,10.15,10.1]
t = [6.46,6.45,6.45,6.45,6.47,6.47,6.46,6.53,6.52,6.52,6.53,6.53,6.54,6.53,6.52,6.5,6.48,6.43,6.32,6.22,6.02,5.71,5.29,4.78,4.23,3.63,3.02,2.41,1.9,1.4,0.97,0.675,0.449,0.269,0.158,0.092,0.053,0.033,0.0189,0.011,0.00698,0.00459,0.00347,0.00247,0.00234,0.00207]
num = 6.47
res = []
for val in t:
    res.append(val/num)
plt.plot(p,res,'o--')
plt.xlabel('knife edge position in mm')
plt.ylabel('power meter reading')
plt.title('D= 300')
y_f = interp1d(p,res,'linear')
y_f(11.5)
plt.show()

# %%
y_f = interp1d(p,res,'linear')
y_f(10.922)
# Out:
# array(0.2503864)

# %%
y_f = interp1d(p,res,'linear')
y_f(11.2072)
# Out:
# array(0.75014529)
